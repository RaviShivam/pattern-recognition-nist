# %% [markdown]
# Best performance for full dataset:
# RAW: (360, 85), 0.96499999999999997
# PCA: (80, 41), 0.96699999999999997)
# ICA: ((80, 51), 0.72070000000000012)

# %%
print(1)

# %%
from prutils import *
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)


mlp = MLPClassifier(hidden_layer_sizes=(360, 85), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
pca_batch_raw = run_PCA_experiment(mlp, RAW_PIXELS_DATASET, max_components=80, batch=True)

mlp = MLPClassifier(hidden_layer_sizes=(80, 41), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
pca_batch_features = run_PCA_experiment(mlp, IM_FEATURES_DATASET, max_components=80, batch=True)

plot_performance([pca_batch_raw, pca_batch_features], show_results=False, save_to_file="mlp_pca")

# %%
from prutils import *
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)


mlp = MLPClassifier(hidden_layer_sizes=(80, 51), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
ica_batch_raw = run_ICA_experiment(mlp, RAW_PIXELS_DATASET, max_components = 30, batch=True)

mlp = MLPClassifier(hidden_layer_sizes=(80, 51), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
ica_batch_features = run_ICA_experiment(mlp, IM_FEATURES_DATASET, max_components=30, batch=True)

plot_performance([ica_batch_raw, ica_batch_features], show_results=False, save_to_file="mlp_ica")

# %%
from prutils import *
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)


mlp = MLPClassifier(hidden_layer_sizes=(80, 51), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
kpca_batch_raw = run_KPCA_experiment(mlp, RAW_PIXELS_DATASET, max_components = 30, batch=True)

mlp = MLPClassifier(hidden_layer_sizes=(80, 51), max_iter=150, alpha=1e-5,
                                solver='lbfgs', tol=1e-4, random_state=1,
                                learning_rate_init=.1)
kpca_batch_features = run_KPCA_experiment(mlp, IM_FEATURES_DATASET, max_components=30, batch=True)

plot_performance([kpca_batch_raw, kpca_batch_features], show_results=False, save_to_file="mlp_ica")

print(kpca_batch_raw[max(kpca_batch_raw, key=kpca_batch_raw.get)])
print(kpca_batch_features[max(kpca_batch_features, key=kpca_batch_features.get)])
# Out:
# ...
#   3%|▎         | 1/29 [00:08<04:06,  8.79s/it]

# %%
print(pca_batch_features[max(pca_batch_features, key=pca_batch_features.get)])
# Out:
# 38.14
